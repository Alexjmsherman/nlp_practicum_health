# %% [markdown]
# #### Author: Alex Sherman

# %% [markdown]
# # Document Clustering Homework
#
# In this homework, we will cluster Oracle 10-K reports from 1994 to 2015.
#
# Text has separated been extracted from the reports into sections, separating the section_name from the section_text. Neither the sections or section text is perfectly structured, so we must deal with the inconsistencies in the text.
#
# Our task is to cluster the sections into logical groups.

# %%
import pandas as pd

# %%
path = r'..\2_dataset\oracle_10k.csv'
sections = pd.read_csv(path, encoding='iso-8859-1')

# %% [markdown]
# ### Observe the data

# %%
sections.head(20)
# Out:
#     Unnamed: 0  section_id                                    filename  \
# 0            0           1  oracle-corporation_annual_report_1994.docx
# 1            1           2  oracle-corporation_annual_report_1994.docx
# 2            2           3  oracle-corporation_annual_report_1994.docx
# 3            3           4  oracle-corporation_annual_report_1994.docx
# 4            4           5  oracle-corporation_annual_report_1994.docx
# 5            5           6  oracle-corporation_annual_report_1994.docx
# 6            6           7  oracle-corporation_annual_report_1994.docx
# 7            7           8  oracle-corporation_annual_report_1994.docx
# 8            8           9  oracle-corporation_annual_report_1994.docx
# 9            9          10  oracle-corporation_annual_report_1994.docx
# 10          10          11  oracle-corporation_annual_report_1994.docx
# 11          11          12  oracle-corporation_annual_report_1994.docx
# 12          12          13  oracle-corporation_annual_report_1994.docx
# 13          13          14  oracle-corporation_annual_report_1994.docx
# 14          14          15  oracle-corporation_annual_report_1994.docx
# 15          15          16  oracle-corporation_annual_report_1994.docx
# 16          16          17  oracle-corporation_annual_report_1994.docx
# 17          17          18  oracle-corporation_annual_report_1994.docx
# 18          18          19  oracle-corporation_annual_report_1994.docx
# 19          19          20  oracle-corporation_annual_report_1994.docx
#
#                                          section_name  \
# 0                            ORACLE SYSTEMS FORM 10-K
# 1                              REDWOOD CITY, CA 94065
# 2                                     CIK\t0000777676
# 3                          ORACLE CORP /DE/ FORM 10-K
# 4                  SECURITIES AND EXCHANGE COMMISSION
# 5   FORM 10-K [X] ANNUAL REPORT PURSUANT TO SECTIO...
# 6   SECURITIES REGISTERED PURSUANT TO SECTION 12(B...
# 7   ORACLE SYSTEMS CORPORATION 1994 FORM 10-K ANNU...
# 8                             PART I ITEM 1. BUSINESS
# 9                                          BACKGROUND
# 10                        PRODUCT DEVELOPMENT HISTORY
# 11                                           PRODUCTS
# 12                      COOPERATIVE SERVER TECHNOLOGY
# 13                COOPERATIVE DEVELOPMENT ENVIRONMENT
# 14                     END USER APPLICATIONS PRODUCTS
# 15                                   PRODUCT FEATURES
# 16  HIGH PERFORMANCE AND AVAILABILITY FOR OLTP ENV...
# 17  COOPERATIVE AND DISTRIBUTED PROCESSING CAPABIL...
# 18  DECLARATIVE AND PROCEDURAL DATA INTEGRITY FEAT...
# 19  SUPPORT FOR TIGHTLY AND LOOSELY-COUPLED PARALL...
#
#                                          section_text  clusters
# 0   (Annual Report) Filed 07/27/94 for the Period ...        17
# 1                               Telephone\t6505067000         5
# 2   SIC Code\t7372 - Prepackaged Software Industry...         5
# 3   (Annual Report) Filed 7/27/1994 For Period End...        17
# 4                              Washington, D.C. 20549         5
# 5   (Exact name of registrant as specified in its ...         5
# 6   (Title of class) Indicate by check mark whethe...         5
# 7                                                   i        17
# 8   The Company designs, develops, markets, and su...         1
# 9   Computer software can be classified into two b...         5
# 10  In 1976, IBM published the specifications for ...         6
# 11  The Company's products are contained within th...         5
# 12  The Company's Cooperative Server Technology ("...         5
# 13  The Company's Cooperative Development Environm...         6
# 14  The Company's Oracle Financial products consis...         5
# 15  The Company believes that the principal compet...         5
# 16  The Company participates in the on-line transa...         5
# 17  The ORACLE relational DBMS works with the Comp...         5
# 18  ORACLE7 provides advanced capabilities for cen...         5
# 19  The Parallel Server configuration of ORACLE7 p...         5

# %% [markdown]
# ### Create X (why no y?)

# %%
X = sections['section_name']

# %% [markdown]
# ### Create a CountVectorizer or TfidfVectorizer
#
# Test out differnt parameters of the vect (e.g. stop_words='english' or None) to observe how it changes the clusters

# %%
# import a vectorizer

# instantiate the vectorizer

# fit_transform the vectorizer

# %% [markdown]
# ### Cluster the sections
#
# Start with KMeans clustering, but feel free to try out other clustering methods afterwards

# %%
# import a clustering model

# instanitate and fit the clustering model

# %% [markdown]
# ### Observe the clusters
#
# - Add the labels_ back to the original dataframe
# - Sort the values by the cluster to analyze the clusters one by one, observing which sections were placed into each cluster

# %%
# add the labels_ back to the sections dataframe

# %%
# sort and observe the clusters

# %%
# optional helper to observe clusters
for label in set(km.labels_):
    print(sections[sections.clusters == label][['section_name','clusters']].head(10))
    print()
# Out:
#                                           section_name  clusters
# 40                             OTHER INCOME (EXPENSE):         0
# 41                         PROVISION FOR INCOME TAXES:         0
# 77                                        INCOME TAXES         0
# 141                            OTHER INCOME (EXPENSE):         0
# 142                        PROVISION FOR INCOME TAXES:         0
# 160  OPERATING  INCOME................................         0
# 161  INCOME BEFORE PROVISION FOR INCOME TAXES AND C...         0
# 180                                       INCOME TAXES         0
# 247                        PROVISION FOR INCOME TAXES:         0
# 271  OPERATING  INCOME...........................\t...         0
#
#                                           section_name  clusters
# 8                              PART I ITEM 1. BUSINESS         1
# 21         CONSULTING, EDUCATION, AND SUPPORT SERVICES         1
# 105                            PART I ITEM 1. BUSINESS         1
# 120        CONSULTING, EDUCATION, AND SUPPORT SERVICES         1
# 219                            PART I ITEM 1. BUSINESS         1
# 225  APPLICATION DEVELOPMENT AND BUSINESS INTELLIGE...         1
# 226       CLIENT SERVER BUSINESS APPLICATIONS PRODUCTS         1
# 227         CONSULTING, EDUCATION AND SUPPORT SERVICES         1
# 328                            PART I ITEM 1. BUSINESS         1
# 333  APPLICATION DEVELOPMENT AND BUSINESS INTELLIGE...         1
#
#                                           section_name  clusters
# 35   PART II ITEM 5. MARKET FOR REGISTRANT'S COMMON...         2
# 57   LIABILITIES AND STOCKHOLDERS' EQUITY CURRENT L...         2
# 81             STOCKHOLDERS' EQUITY STOCK OPTION PLANS         2
# 135  PART II ITEM 5. MARKET FOR REGISTRANT'S COMMON...         2
# 158  ORACLE CORPORATION CONSOLIDATED BALANCE SHEETS...         2
# 164  ORACLE CORPORATION CONSOLIDATED STATEMENTS OF ...         2
# 188            STOCKHOLDERS' EQUITY STOCK OPTION PLANS         2
# 240  PART II ITEM 5. MARKET FOR REGISTRANT'S COMMON...         2
# 267  ========== ========== LIABILITIES AND STOCKHOL...         2
# 274  ORACLE CORPORATION CONSOLIDATED STATEMENTS OF ...         2
#
#                                           section_name  clusters
# 31                                  ITEM 2. PROPERTIES         3
# 33   ITEM 4. SUBMISSION OF MATTERS TO A VOTE OF SEC...         3
# 34       ITEM 4A. EXECUTIVE OFFICERS OF THE REGISTRANT         3
# 47   PART III ITEM 10. DIRECTORS AND EXECUTIVE OFFI...         3
# 48                     ITEM 11. EXECUTIVE COMPENSATION         3
# 49   ITEM 12. SECURITY OWNERSHIP OF CERTAIN BENEFIC...         3
# 130                                 ITEM 2. PROPERTIES         3
# 132  ITEM 4. SUBMISSION OF MATTERS TO A VOTE OF SEC...         3
# 133      ITEM 4A. EXECUTIVE OFFICERS OF THE REGISTRANT         3
# 148  PART III ITEM 10. DIRECTORS AND EXECUTIVE OFFI...         3
#
#                                           section_name  clusters
# 63   ORACLE SYSTEMS CORPORATION CONSOLIDATED STATEM...         4
# 64               CASH FLOWS FROM INVESTING ACTIVITIES:         4
# 65               CASH FLOWS FROM FINANCING ACTIVITIES:         4
# 70                            STATEMENTS OF CASH FLOWS         4
# 71                           CASH AND CASH INVESTMENTS         4
# 165  ORACLE CORPORATION CONSOLIDATED STATEMENTS OF ...         4
# 166                         CASH AND CASH EQUIVALENTS:         4
# 171                           STATEMENTS OF CASH FLOWS         4
# 275  ORACLE CORPORATION CONSOLIDATED STATEMENTS OF ...         4
# 276              CASH FLOWS FROM INVESTING ACTIVITIES:         4
#
#                                          section_name  clusters
# 1                              REDWOOD CITY, CA 94065         5
# 2                                     CIK\t0000777676         5
# 4                  SECURITIES AND EXCHANGE COMMISSION         5
# 5   FORM 10-K [X] ANNUAL REPORT PURSUANT TO SECTIO...         5
# 6   SECURITIES REGISTERED PURSUANT TO SECTION 12(B...         5
# 9                                          BACKGROUND         5
# 11                                           PRODUCTS         5
# 12                      COOPERATIVE SERVER TECHNOLOGY         5
# 14                     END USER APPLICATIONS PRODUCTS         5
# 15                                   PRODUCT FEATURES         5
#
#                                  section_name  clusters
# 10                PRODUCT DEVELOPMENT HISTORY         6
# 13        COOPERATIVE DEVELOPMENT ENVIRONMENT         6
# 26                        PRODUCT DEVELOPMENT         6
# 74                 SOFTWARE DEVELOPMENT COSTS         6
# 107               PRODUCT DEVELOPMENT HISTORY         6
# 110  APPLICATION DEVELOPMENT AND ACCESS TOOLS         6
# 125                       PRODUCT DEVELOPMENT         6
# 177                SOFTWARE DEVELOPMENT COSTS         6
# 221               PRODUCT DEVELOPMENT HISTORY         6
# 230                       PRODUCT DEVELOPMENT         6
#
#                                            section_name  clusters
# 60    SOFTWARE REVENUE RECOGNITION METHOD, NET EARNI...         7
# 76                                  REVENUE RECOGNITION         7
# 179                                 REVENUE RECOGNITION         7
# 293                                 REVENUE RECOGNITION         7
# 404                                 REVENUE RECOGNITION         7
# 566                                 REVENUE RECOGNITION         7
# 695                                 REVENUE RECOGNITION         7
# 808                                 REVENUE RECOGNITION         7
# 926                                 REVENUE RECOGNITION         7
# 1114                              NEW SOFTWARE LICENSES         7
#
#                                           section_name  clusters
# 101  SECURITIES AND EXCHANGE COMMISSION WASHINGTON ...         8
# 155                      EXHIBIT NUMBER\tEXHIBIT TITLE         8
# 202                                  NAME\tTITLE\tDATE         8
# 203  ORACLE CORPORATION INDEX OF EXHIBITS EXHIBIT #...         8
# 204  EXHIBIT 3.12 CERTIFICATE OF AMENDMENT OF CERTI...         8
# 208  EXHIBIT 21.01 ORACLE CORPORATION FEDERAL I. D....         8
# 209  EXHIBIT 21.01 (CONTINUED) ORACLE CORPORATION F...         8
# 210  EXHIBIT 23.01 CONSENT OF INDEPENDENT PUBLIC AC...         8
# 216  SECURITIES AND EXCHANGE COMMISSION WASHINGTON ...         8
# 262                      EXHIBIT NUMBER\tEXHIBIT TITLE         8
#
#                                           section_name  clusters
# 36                     ITEM 6. SELECTED FINANCIAL DATA         9
# 37   ITEM 7. MANAGEMENT'S DISCUSSION AND ANALYSIS O...         9
# 45   ITEM 8. FINANCIAL STATEMENTS AND SUPPLEMENTARY...         9
# 46   ITEM 9. CHANGES IN AND DISAGREEMENTS WITH ACCO...         9
# 51   PART IV ITEM 14. EXHIBITS, FINANCIAL STATEMENT...         9
# 68                       BASIS OF FINANCIAL STATEMENTS         9
# 138  ITEM 7. MANAGEMENT'S DISCUSSION AND ANALYSIS O...         9
# 146  ITEM 8. FINANCIAL STATEMENTS AND SUPPLEMENTARY...         9
# 147  ITEM 9. CHANGES IN AND DISAGREEMENTS WITH ACCO...         9
# 152  PART IV ITEM 14. EXHIBITS, FINANCIAL STATEMENT...         9
#
#                                           section_name  clusters
# 137  ITEM 6. SELECTED FINANCIAL DATA YEAR ENDED MAY...        10
# 145  FISCAL 1995 QUARTER ENDED FISCAL 1994 QUARTER ...        10
# 159  ORACLE CORPORATION CONSOLIDATED STATEMENTS OF ...        10
# 183  YEAR ENDED MAY 31, ---------\t--------- (IN TH...        10
# 184                 YEAR ENDED MAY 31,\t(IN THOUSANDS)        10
# 186  YEAR ENDED MAY 31, -------\t------- (IN THOUSA...        10
# 194  YEAR ENDED MAY 31, ---------\t--------\t------...        10
# 195                                 YEAR ENDED MAY 31,        10
# 242  ITEM 6. SELECTED FINANCIAL DATA YEAR ENDED MAY...        10
# 244  REVENUES: FISCAL YEAR 1996 CHANGE FISCAL YEAR ...        10
#
#                       section_name  clusters
# 28   PRODUCT AND SERVICES REVENUES        11
# 38                       REVENUES:        11
# 127  PRODUCT AND SERVICES REVENUES        11
# 139                      REVENUES:        11
# 232  PRODUCT AND SERVICES REVENUES        11
# 340  PRODUCT AND SERVICES REVENUES        11
# 501  PRODUCT AND SERVICES REVENUES        11
# 628  PRODUCT AND SERVICES REVENUES        11
# 638                      REVENUES:        11
# 668                       REVENUES        11
#
#                                           section_name  clusters
# 82                                    NON-PLAN OPTIONS        12
# 83                                 STOCK PURCHASE PLAN        12
# 84                             SHAREHOLDER RIGHTS PLAN        12
# 94   ORACLE SYSTEMS CORPORATION INDEX OF EXHIBITS A...        12
# 190                                STOCK PURCHASE PLAN        12
# 191                            SHAREHOLDER RIGHTS PLAN        12
# 305                                STOCK PURCHASE PLAN        12
# 306                            SHAREHOLDER RIGHTS PLAN        12
# 418                            SHAREHOLDER RIGHTS PLAN        12
# 582                            SHAREHOLDER RIGHTS PLAN        12
#
#                   section_name  clusters
# 32   ITEM 3. LEGAL PROCEEDINGS        13
# 131  ITEM 3. LEGAL PROCEEDINGS        13
# 236  ITEM 3. LEGAL PROCEEDINGS        13
# 344  ITEM 3. LEGAL PROCEEDINGS        13
# 505  ITEM 3. LEGAL PROCEEDINGS        13
# 632  ITEM 3. LEGAL PROCEEDINGS        13
# 711          LEGAL PROCEEDINGS        13
# 750  ITEM 3. LEGAL PROCEEDINGS        13
# 827          LEGAL PROCEEDINGS        13
# 884  ITEM 3. LEGAL PROCEEDINGS        13
#
#                                            section_name  clusters
# 291                                        ACQUISITIONS        14
# 402                                        ACQUISITIONS        14
# 564                                        ACQUISITIONS        14
# 702                                      6.ACQUISITIONS        14
# 814                                        ACQUISITIONS        14
# 1512                                       ACQUISITIONS        14
# 1516    OTHER ACQUISITIONS OF BUSINESSES AND TECHNOLOGY        14
# 1595                       FISCAL 2006\t\t\tFISCAL 2005        14
# 1608                                       ACQUISITIONS        14
# 1675  ACQUISITIONS FISCAL 2006 ACQUISITIONS SIEBEL S...        14
#
#                            section_name  clusters
# 42   NET INCOME AND EARNINGS PER SHARE:        15
# 78                   EARNINGS PER SHARE        15
# 143  NET INCOME AND EARNINGS PER SHARE:        15
# 181                  EARNINGS PER SHARE        15
# 296                  EARNINGS PER SHARE        15
# 356  NET INCOME AND EARNINGS PER SHARE:        15
# 407                  EARNINGS PER SHARE        15
# 569                  EARNINGS PER SHARE        15
# 646  NET INCOME AND EARNINGS PER SHARE:        15
# 703                  EARNINGS PER SHARE        15
#
#      section_name  clusters
# 30      EMPLOYEES        16
# 129     EMPLOYEES        16
# 234     EMPLOYEES        16
# 342     EMPLOYEES        16
# 503     EMPLOYEES        16
# 630     EMPLOYEES        16
# 748     EMPLOYEES        16
# 881     EMPLOYEES        16
# 972     EMPLOYEES        16
# 1126    EMPLOYEES        16
#
#                                          section_name  clusters
# 0                            ORACLE SYSTEMS FORM 10-K        17
# 3                          ORACLE CORP /DE/ FORM 10-K        17
# 7   ORACLE SYSTEMS CORPORATION 1994 FORM 10-K ANNU...        17
# 53  REPORT OF INDEPENDENT PUBLIC ACCOUNTANTS TO OR...        17
# 54  ORACLE SYSTEMS CORPORATION CONSOLIDATED BALANC...        17
# 59  ORACLE SYSTEMS CORPORATION CONSOLIDATED STATEM...        17
# 62  ORACLE SYSTEMS CORPORATION CONSOLIDATED STATEM...        17
# 67  ORACLE SYSTEMS CORPORATION NOTES TO CONSOLIDAT...        17
# 88  SCHEDULE II ORACLE SYSTEMS CORPORATION AMOUNTS...        17
# 89  SCHEDULE VIII ORACLE SYSTEMS CORPORATION VALUA...        17
#
#     section_name  clusters
# 73      PROPERTY        18
# 87    LITIGATION        18
# 176     PROPERTY        18
# 289     PROPERTY        18
# 400     PROPERTY        18
# 428   LITIGATION        18
# 562     PROPERTY        18
# 691     PROPERTY        18
# 699   2.PROPERTY        18
# 804     PROPERTY        18
#
#                                           section_name  clusters
# 69                        FOREIGN CURRENCY TRANSLATION        19
# 72                        CONCENTRATION OF CREDIT RISK        19
# 169                       FOREIGN CURRENCY TRANSLATION        19
# 175                       CONCENTRATION OF CREDIT RISK        19
# 282                       FOREIGN CURRENCY TRANSLATION        19
# 288                       CONCENTRATION OF CREDIT RISK        19
# 393                       FOREIGN CURRENCY TRANSLATION        19
# 523  ITEM 7A. QUANTITATIVE AND QUALITATIVE DISCLOSU...        19
# 554                       FOREIGN CURRENCY TRANSLATION        19
# 560                       CONCENTRATION OF CREDIT RISK        19

# %% [markdown]
# #### Describe each cluster (optional)
#
# The below code runs a topic model (LatentDirichletAllocation) on the text of each of the cluster section_names one by one. It then returns the top five terms that best describe the topics.
#
# - This code assumes your clustering model is named km

# %%
from sklearn.decomposition import LatentDirichletAllocation

def topic_model(fit_vect, n_topics=1):
    """
    :param fit_vect: vect fit with cluster text
    :param n_topics: num topics (often 1) to explain cluster
    
    :return: fit topic model
    """

    # lda for topic model
    lda = LatentDirichletAllocation(n_components=n_topics, learning_method='batch' , random_state=42)
    lda.fit(fit_vect)

    return lda

    
def topic_explanations(vect, model, n_top_words=5):
    """
    :param vect: fit vect
    :param model: fit topic model
    :param n_top_words: terms to describe topic
    
    :return: list of terms describing topic
    """

    # get feature names (all words from documents)
    feature_names = vect.get_feature_names()

    # only one topic, so fine to have return in for loop
    for topic in model.components_:
        return " ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]])


for label in set(km.labels_):
    # filter to only the text in one cluster
    cluster_text = sections[sections.clusters == label]['section_name']
    
    # fit a vector on the text in the cluster
    cluster_vect = TfidfVectorizer()
    fit_vect = cluster_vect.fit_transform(cluster_text)
    
    # run lda (topic model)
    lda_model = topic_model(fit_vect)
    
    # explain the text in the topic
    topic_explanation = topic_explanations(vect=cluster_vect, model=lda_model, n_top_words=5)
    
    print('Cluster={} | {}'.format(label, topic_explanation))
# Out:
# Cluster=0 | taxes income for net accounting
# Cluster=1 | business services software item and
# Cluster=2 | equity stockholders and liabilities stock
# Cluster=3 | item executive of compensation properties
# Cluster=4 | cash flows from and activities
# Cluster=5 | of and the information to
# Cluster=6 | development research and product software
# Cluster=7 | software recognition revenue and elements
# Cluster=8 | exhibit of title date name
# Cluster=9 | financial and of exhibits item
# Cluster=10 | 31 may year ended in
# Cluster=11 | revenues and support the software
# Cluster=12 | plan restructuring stock purchase fiscal
# Cluster=13 | legal proceedings item contingencies other
# Cluster=14 | acquisitions fiscal other of inc
# Cluster=15 | share per earnings net income
# Cluster=16 | employees the significant registrant officers
# Cluster=17 | oracle corporation to statements consolidated
# Cluster=18 | property litigation other intellectual sap
# Cluster=19 | currency foreign risk translation item
