# %% [markdown]
# #### Author: Alex Sherman

# %% [markdown]
# # Document Clustering Homework
#
# In this homework, we will cluster Oracle 10-K reports from 1994 to 2015.
#
# Text has separated been extracted from the reports into sections, separating the section_name from the section_text. Neither the sections or section text is perfectly structured, so we must deal with the inconsistencies in the text.
#
# Our task is to cluster the sections into logical groups.

# %%
import pandas as pd

# %%
path = r'..\..\2_dataset\oracle_10k.csv'
sections = pd.read_csv(path, encoding='iso-8859-1')

# %% [markdown]
# ### Observe the data

# %%
sections.head(20)
# Out:
#     Unnamed: 0  section_id                                    filename  \
# 0            0           1  oracle-corporation_annual_report_1994.docx
# 1            1           2  oracle-corporation_annual_report_1994.docx
# 2            2           3  oracle-corporation_annual_report_1994.docx
# 3            3           4  oracle-corporation_annual_report_1994.docx
# 4            4           5  oracle-corporation_annual_report_1994.docx
# 5            5           6  oracle-corporation_annual_report_1994.docx
# 6            6           7  oracle-corporation_annual_report_1994.docx
# 7            7           8  oracle-corporation_annual_report_1994.docx
# 8            8           9  oracle-corporation_annual_report_1994.docx
# 9            9          10  oracle-corporation_annual_report_1994.docx
# 10          10          11  oracle-corporation_annual_report_1994.docx
# 11          11          12  oracle-corporation_annual_report_1994.docx
# 12          12          13  oracle-corporation_annual_report_1994.docx
# 13          13          14  oracle-corporation_annual_report_1994.docx
# 14          14          15  oracle-corporation_annual_report_1994.docx
# 15          15          16  oracle-corporation_annual_report_1994.docx
# 16          16          17  oracle-corporation_annual_report_1994.docx
# 17          17          18  oracle-corporation_annual_report_1994.docx
# 18          18          19  oracle-corporation_annual_report_1994.docx
# 19          19          20  oracle-corporation_annual_report_1994.docx
#
#                                          section_name  \
# 0                            ORACLE SYSTEMS FORM 10-K
# 1                              REDWOOD CITY, CA 94065
# 2                                     CIK\t0000777676
# 3                          ORACLE CORP /DE/ FORM 10-K
# 4                  SECURITIES AND EXCHANGE COMMISSION
# 5   FORM 10-K [X] ANNUAL REPORT PURSUANT TO SECTIO...
# 6   SECURITIES REGISTERED PURSUANT TO SECTION 12(B...
# 7   ORACLE SYSTEMS CORPORATION 1994 FORM 10-K ANNU...
# 8                             PART I ITEM 1. BUSINESS
# 9                                          BACKGROUND
# 10                        PRODUCT DEVELOPMENT HISTORY
# 11                                           PRODUCTS
# 12                      COOPERATIVE SERVER TECHNOLOGY
# 13                COOPERATIVE DEVELOPMENT ENVIRONMENT
# 14                     END USER APPLICATIONS PRODUCTS
# 15                                   PRODUCT FEATURES
# 16  HIGH PERFORMANCE AND AVAILABILITY FOR OLTP ENV...
# 17  COOPERATIVE AND DISTRIBUTED PROCESSING CAPABIL...
# 18  DECLARATIVE AND PROCEDURAL DATA INTEGRITY FEAT...
# 19  SUPPORT FOR TIGHTLY AND LOOSELY-COUPLED PARALL...
#
#                                          section_text
# 0   (Annual Report) Filed 07/27/94 for the Period ...
# 1                               Telephone\t6505067000
# 2   SIC Code\t7372 - Prepackaged Software Industry...
# 3   (Annual Report) Filed 7/27/1994 For Period End...
# 4                              Washington, D.C. 20549
# 5   (Exact name of registrant as specified in its ...
# 6   (Title of class) Indicate by check mark whethe...
# 7                                                   i
# 8   The Company designs, develops, markets, and su...
# 9   Computer software can be classified into two b...
# 10  In 1976, IBM published the specifications for ...
# 11  The Company's products are contained within th...
# 12  The Company's Cooperative Server Technology ("...
# 13  The Company's Cooperative Development Environm...
# 14  The Company's Oracle Financial products consis...
# 15  The Company believes that the principal compet...
# 16  The Company participates in the on-line transa...
# 17  The ORACLE relational DBMS works with the Comp...
# 18  ORACLE7 provides advanced capabilities for cen...
# 19  The Parallel Server configuration of ORACLE7 p...

# %% [markdown]
# ### Create X (why no y?)

# %%
X = sections['section_name']

# %% [markdown]
# ### Create a CountVectorizer or TfidfVectorizer
#
# Test out differnt parameters of the vect (e.g. stop_words='english' or None) to observe how it changes the clusters

# %%
# import a vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# instantiate the vectorizer
vect = TfidfVectorizer(stop_words='english')

# fit_transform the vectorizer
fit_vect = vect.fit_transform(X)

# %% [markdown]
# ### Cluster the sections
#
# Start with KMeans clustering, but feel free to try out other clustering methods afterwards

# %%
# import a clustering model
from sklearn.cluster import KMeans

# instanitate and fit the clustering model
km = KMeans(n_clusters=20)
km.fit(fit_vect)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=20, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ### Observe the clusters
#
# - Add the labels_ back to the original dataframe
# - Sort the values by the cluster to analyze the clusters one by one, observing which sections were placed into each cluster

# %%
# add the labels_ back to the sections dataframe
sections['clusters'] = km.labels_

# %%
# sort and observe the clusters
sections.sort_values('clusters').head()
# Out:
#       Unnamed: 0  section_id                                    filename  \
# 3333        3333        3334  oracle-corporation_annual_report_2014.docx
# 167          167         168  oracle-corporation_annual_report_1995.docx
# 168          168         169  oracle-corporation_annual_report_1995.docx
# 2096        2096        2097  oracle-corporation_annual_report_2008.docx
# 2098        2098        2099  oracle-corporation_annual_report_2008.docx
#
#                                            section_name  \
# 3333                      BASIS OF FINANCIAL STATEMENTS
# 167   ORACLE CORPORATION NOTES TO CONSOLIDATED FINAN...
# 168                       BASIS OF FINANCIAL STATEMENTS
# 2096  ORACLE CORPORATION NOTES TO CONSOLIDATED FINAN...
# 2098  ORACLE CORPORATION NOTES TO CONSOLIDATED FINAN...
#
#                                            section_text  clusters
# 3333  The consolidated financial statements included...         0
# 167   Oracle Corporation designs, develops, markets,...         0
# 168   The consolidated financial statements include ...         0
# 2096      Deferred revenues consisted of the following:         0
# 2098  We lease certain facilities and furniture and ...         0

# %%
# optional helper to observe clusters
for label in set(km.labels_):
    print(sections[sections.clusters == label][['section_name','clusters']].head(10))
    print()
# Out:
#                                           section_name  clusters
# 36                     ITEM 6. SELECTED FINANCIAL DATA         0
# 37   ITEM 7. MANAGEMENT'S DISCUSSION AND ANALYSIS O...         0
# 45   ITEM 8. FINANCIAL STATEMENTS AND SUPPLEMENTARY...         0
# 51   PART IV ITEM 14. EXHIBITS, FINANCIAL STATEMENT...         0
# 67   ORACLE SYSTEMS CORPORATION NOTES TO CONSOLIDAT...         0
# 68                       BASIS OF FINANCIAL STATEMENTS         0
# 138  ITEM 7. MANAGEMENT'S DISCUSSION AND ANALYSIS O...         0
# 146  ITEM 8. FINANCIAL STATEMENTS AND SUPPLEMENTARY...         0
# 152  PART IV ITEM 14. EXHIBITS, FINANCIAL STATEMENT...         0
# 167  ORACLE CORPORATION NOTES TO CONSOLIDATED FINAN...         0
#
#                                           section_name  clusters
# 0                             ORACLE SYSTEMS FORM 10-K         1
# 20   PORTABILITY ACROSS COMPUTER HARDWARE AND OPERA...         1
# 22                                 SYSTEMS INTEGRATION         1
# 93                          ORACLE SYSTEMS CORPORATION         1
# 97                            ORACLE SYSTEMS FORM 10-K         1
# 119  PORTABILITY ACROSS COMPUTER HARDWARE AND OPERA...         1
# 121                                SYSTEMS INTEGRATION         1
# 205                        ORACLE SYSTEMS CORPORATION,         1
# 212                           ORACLE SYSTEMS FORM 10-K         1
# 321                           ORACLE SYSTEMS FORM 10-K         1
#
#                   section_name  clusters
# 8      PART I ITEM 1. BUSINESS         2
# 31          ITEM 2. PROPERTIES         2
# 32   ITEM 3. LEGAL PROCEEDINGS         2
# 105    PART I ITEM 1. BUSINESS         2
# 130         ITEM 2. PROPERTIES         2
# 131  ITEM 3. LEGAL PROCEEDINGS         2
# 219    PART I ITEM 1. BUSINESS         2
# 235         ITEM 2. PROPERTIES         2
# 236  ITEM 3. LEGAL PROCEEDINGS         2
# 328    PART I ITEM 1. BUSINESS         2
#
#                                 section_name  clusters
# 81   STOCKHOLDERS' EQUITY STOCK OPTION PLANS         3
# 188  STOCKHOLDERS' EQUITY STOCK OPTION PLANS         3
# 294  ACCOUNTING FOR STOCK-BASED COMPENSATION         3
# 303  STOCKHOLDERS' EQUITY STOCK OPTION PLANS         3
# 405  ACCOUNTING FOR STOCK-BASED COMPENSATION         3
# 414  STOCKHOLDERS' EQUITY STOCK OPTION PLANS         3
# 567  ACCOUNTING FOR STOCK-BASED COMPENSATION         3
# 579  STOCKHOLDERS' EQUITY STOCK OPTION PLANS         3
# 696  ACCOUNTING FOR STOCK-BASED COMPENSATION         3
# 704  STOCKHOLDERS' EQUITY STOCK OPTION PLANS         3
#
#                                           section_name  clusters
# 54   ORACLE SYSTEMS CORPORATION CONSOLIDATED BALANC...         4
# 59   ORACLE SYSTEMS CORPORATION CONSOLIDATED STATEM...         4
# 62   ORACLE SYSTEMS CORPORATION CONSOLIDATED STATEM...         4
# 78                                  EARNINGS PER SHARE         4
# 158  ORACLE CORPORATION CONSOLIDATED BALANCE SHEETS...         4
# 164  ORACLE CORPORATION CONSOLIDATED STATEMENTS OF ...         4
# 181                                 EARNINGS PER SHARE         4
# 250  FISCAL 1996 QUARTER ENDED --------------------...         4
# 265  ORACLE CORPORATION CONSOLIDATED BALANCE SHEETS...         4
# 274  ORACLE CORPORATION CONSOLIDATED STATEMENTS OF ...         4
#
#                                          section_name  clusters
# 1                              REDWOOD CITY, CA 94065         5
# 2                                     CIK\t0000777676         5
# 3                          ORACLE CORP /DE/ FORM 10-K         5
# 4                  SECURITIES AND EXCHANGE COMMISSION         5
# 5   FORM 10-K [X] ANNUAL REPORT PURSUANT TO SECTIO...         5
# 7   ORACLE SYSTEMS CORPORATION 1994 FORM 10-K ANNU...         5
# 9                                          BACKGROUND         5
# 11                                           PRODUCTS         5
# 12                      COOPERATIVE SERVER TECHNOLOGY         5
# 14                     END USER APPLICATIONS PRODUCTS         5
#
#                                            section_name  clusters
# 69                         FOREIGN CURRENCY TRANSLATION         6
# 169                        FOREIGN CURRENCY TRANSLATION         6
# 282                        FOREIGN CURRENCY TRANSLATION         6
# 393                        FOREIGN CURRENCY TRANSLATION         6
# 554                        FOREIGN CURRENCY TRANSLATION         6
# 685                        FOREIGN CURRENCY TRANSLATION         6
# 797                        FOREIGN CURRENCY TRANSLATION         6
# 916   FOREIGN CURRENCY TRANSLATION AND DERIVATIVE FI...         6
# 1016  TABLE OF FORWARD CONTRACTS: (DOLLARS IN MILLIO...         6
# 1137  RESULTS OF OPERATIONS CONSTANT CURRENCY PRESEN...         6
#
#                                     section_name  clusters
# 21   CONSULTING, EDUCATION, AND SUPPORT SERVICES         7
# 28                 PRODUCT AND SERVICES REVENUES         7
# 38                                     REVENUES:         7
# 120  CONSULTING, EDUCATION, AND SUPPORT SERVICES         7
# 127                PRODUCT AND SERVICES REVENUES         7
# 139                                    REVENUES:         7
# 227   CONSULTING, EDUCATION AND SUPPORT SERVICES         7
# 232                PRODUCT AND SERVICES REVENUES         7
# 335   CONSULTING, EDUCATION AND SUPPORT SERVICES         7
# 340                PRODUCT AND SERVICES REVENUES         7
#
#                                           section_name  clusters
# 170                        CONTRACT AMOUNT\tFAIR VALUE         8
# 174  AMORTIZED\tAGGREGATE\t\tUNREALIZED COST\tFAIR ...         8
# 284                        CONTRACT AMOUNT\tFAIR VALUE         8
# 287  AMORTIZED AGGREGATE\tUNREALIZED COST\tFAIR VAL...         8
# 394                        CONTRACT AMOUNT\tFAIR VALUE         8
# 398  AMORTIZED AGGREGATE FAIR\t\tUNREALIZED COST\tV...         8
# 559  AMORTIZED AGGREGATE\tUNREALIZED COST BASIS FAI...         8
# 663                              CURRENT ASSETS ASSETS         8
# 781                              CURRENT ASSETS ASSETS         8
# 907                                             ASSETS         8
#
#                                           section_name  clusters
# 46   ITEM 9. CHANGES IN AND DISAGREEMENTS WITH ACCO...         9
# 53   REPORT OF INDEPENDENT PUBLIC ACCOUNTANTS TO OR...         9
# 96           CONSENT OF INDEPENDENT PUBLIC ACCOUNTANTS         9
# 147  ITEM 9. CHANGES IN AND DISAGREEMENTS WITH ACCO...         9
# 156  REPORT OF INDEPENDENT PUBLIC ACCOUNTANTS TO OR...         9
# 173  STATEMENT OF FINANCIAL ACCOUNTING STANDARDS NO...         9
# 210  EXHIBIT 23.01 CONSENT OF INDEPENDENT PUBLIC AC...         9
# 254  ITEM 9. CHANGES IN AND DISAGREEMENTS WITH ACCO...         9
# 263  REPORT OF INDEPENDENT PUBLIC ACCOUNTANTS TO OR...         9
# 319  EXHIBIT 23.01 CONSENT OF INDEPENDENT PUBLIC AC...         9
#
#                                           section_name  clusters
# 40                             OTHER INCOME (EXPENSE):        10
# 41                         PROVISION FOR INCOME TAXES:        10
# 42                  NET INCOME AND EARNINGS PER SHARE:        10
# 77                                        INCOME TAXES        10
# 141                            OTHER INCOME (EXPENSE):        10
# 142                        PROVISION FOR INCOME TAXES:        10
# 143                 NET INCOME AND EARNINGS PER SHARE:        10
# 160  OPERATING  INCOME................................        10
# 161  INCOME BEFORE PROVISION FOR INCOME TAXES AND C...        10
# 180                                       INCOME TAXES        10
#
#                                           section_name  clusters
# 137  ITEM 6. SELECTED FINANCIAL DATA YEAR ENDED MAY...        11
# 145  FISCAL 1995 QUARTER ENDED FISCAL 1994 QUARTER ...        11
# 159  ORACLE CORPORATION CONSOLIDATED STATEMENTS OF ...        11
# 183  YEAR ENDED MAY 31, ---------\t--------- (IN TH...        11
# 184                 YEAR ENDED MAY 31,\t(IN THOUSANDS)        11
# 186  YEAR ENDED MAY 31, -------\t------- (IN THOUSA...        11
# 194  YEAR ENDED MAY 31, ---------\t--------\t------...        11
# 195                                 YEAR ENDED MAY 31,        11
# 242  ITEM 6. SELECTED FINANCIAL DATA YEAR ENDED MAY...        11
# 244  REVENUES: FISCAL YEAR 1996 CHANGE FISCAL YEAR ...        11
#
#                            section_name  clusters
# 25      ADDITIONAL CUSTOMER INFORMATION        12
# 86                  SEGMENT INFORMATION        12
# 118  SUPPORT FOR MULTIMEDIA INFORMATION        12
# 124     ADDITIONAL CUSTOMER INFORMATION        12
# 229     ADDITIONAL CUSTOMER INFORMATION        12
# 310                 SEGMENT INFORMATION        12
# 337     ADDITIONAL CUSTOMER INFORMATION        12
# 426                 SEGMENT INFORMATION        12
# 499     ADDITIONAL CUSTOMER INFORMATION        12
# 708                 SEGMENT INFORMATION        12
#
#                                           section_name  clusters
# 34       ITEM 4A. EXECUTIVE OFFICERS OF THE REGISTRANT        13
# 47   PART III ITEM 10. DIRECTORS AND EXECUTIVE OFFI...        13
# 48                     ITEM 11. EXECUTIVE COMPENSATION        13
# 133      ITEM 4A. EXECUTIVE OFFICERS OF THE REGISTRANT        13
# 148  PART III ITEM 10. DIRECTORS AND EXECUTIVE OFFI...        13
# 149                    ITEM 11. EXECUTIVE COMPENSATION        13
# 238      ITEM 4A. EXECUTIVE OFFICERS OF THE REGISTRANT        13
# 255  PART III ITEM 10. DIRECTORS AND EXECUTIVE OFFI...        13
# 256                    ITEM 11. EXECUTIVE COMPENSATION        13
# 346      ITEM 4A. EXECUTIVE OFFICERS OF THE REGISTRANT        13
#
#                                            section_name  clusters
# 60    SOFTWARE REVENUE RECOGNITION METHOD, NET EARNI...        14
# 74                           SOFTWARE DEVELOPMENT COSTS        14
# 177                          SOFTWARE DEVELOPMENT COSTS        14
# 290                          SOFTWARE DEVELOPMENT COSTS        14
# 401                          SOFTWARE DEVELOPMENT COSTS        14
# 692                          SOFTWARE DEVELOPMENT COSTS        14
# 805                          SOFTWARE DEVELOPMENT COSTS        14
# 1114                              NEW SOFTWARE LICENSES        14
# 1139  NEW SOFTWARE LICENSE AND OTHER:\tNEW SOFTWARE ...        14
# 1276                              SOFTWARE AND SERVICES        14
#
#      section_name  clusters
# 27    COMPETITION        15
# 126   COMPETITION        15
# 231   COMPETITION        15
# 339   COMPETITION        15
# 500   COMPETITION        15
# 627   COMPETITION        15
# 746   COMPETITION        15
# 879   COMPETITION        15
# 970   COMPETITION        15
# 1124  COMPETITION        15
#
#                                           section_name  clusters
# 6    SECURITIES REGISTERED PURSUANT TO SECTION 12(B...        16
# 33   ITEM 4. SUBMISSION OF MATTERS TO A VOTE OF SEC...        16
# 35   PART II ITEM 5. MARKET FOR REGISTRANT'S COMMON...        16
# 49   ITEM 12. SECURITY OWNERSHIP OF CERTAIN BENEFIC...        16
# 50   ITEM 13. CERTAIN RELATIONSHIPS AND RELATED TRA...        16
# 57   LIABILITIES AND STOCKHOLDERS' EQUITY CURRENT L...        16
# 132  ITEM 4. SUBMISSION OF MATTERS TO A VOTE OF SEC...        16
# 135  PART II ITEM 5. MARKET FOR REGISTRANT'S COMMON...        16
# 150  ITEM 12. SECURITY OWNERSHIP OF CERTAIN BENEFIC...        16
# 151  ITEM 13. CERTAIN RELATIONSHIPS AND RELATED TRA...        16
#
#                                  section_name  clusters
# 10                PRODUCT DEVELOPMENT HISTORY        17
# 13        COOPERATIVE DEVELOPMENT ENVIRONMENT        17
# 26                        PRODUCT DEVELOPMENT        17
# 30                                  EMPLOYEES        17
# 39                        OPERATING EXPENSES:        17
# 43            QUARTERLY RESULTS OF OPERATIONS        17
# 107               PRODUCT DEVELOPMENT HISTORY        17
# 110  APPLICATION DEVELOPMENT AND ACCESS TOOLS        17
# 125                       PRODUCT DEVELOPMENT        17
# 129                                 EMPLOYEES        17
#
#                                           section_name  clusters
# 82                                    NON-PLAN OPTIONS        18
# 83                                 STOCK PURCHASE PLAN        18
# 84                             SHAREHOLDER RIGHTS PLAN        18
# 94   ORACLE SYSTEMS CORPORATION INDEX OF EXHIBITS A...        18
# 189  SHARES UNDER OPTION\tOPTION PRICES NON-PLAN OP...        18
# 190                                STOCK PURCHASE PLAN        18
# 191                            SHAREHOLDER RIGHTS PLAN        18
# 252  FACTORS THAT MAY AFFECT FUTURE RESULTS AND MAR...        18
# 305                                STOCK PURCHASE PLAN        18
# 306                            SHAREHOLDER RIGHTS PLAN        18
#
#                                           section_name  clusters
# 63   ORACLE SYSTEMS CORPORATION CONSOLIDATED STATEM...        19
# 64               CASH FLOWS FROM INVESTING ACTIVITIES:        19
# 65               CASH FLOWS FROM FINANCING ACTIVITIES:        19
# 70                            STATEMENTS OF CASH FLOWS        19
# 71                           CASH AND CASH INVESTMENTS        19
# 165  ORACLE CORPORATION CONSOLIDATED STATEMENTS OF ...        19
# 166                         CASH AND CASH EQUIVALENTS:        19
# 171                           STATEMENTS OF CASH FLOWS        19
# 275  ORACLE CORPORATION CONSOLIDATED STATEMENTS OF ...        19
# 276              CASH FLOWS FROM INVESTING ACTIVITIES:        19

# %% [markdown]
# #### Describe each cluster (optional)
#
# The below code runs a topic model (LatentDirichletAllocation) on the text of each of the cluster section_names one by one. It then returns the top five terms that best describe the topics.
#
# - This code assumes your clustering model is named km

# %%
from sklearn.decomposition import LatentDirichletAllocation

def topic_model(fit_vect, n_topics=1):
    """
    :param fit_vect: vect fit with cluster text
    :param n_topics: num topics (often 1) to explain cluster
    
    :return: fit topic model
    """

    # lda for topic model
    lda = LatentDirichletAllocation(n_components=n_topics, learning_method='batch' , random_state=42)
    lda.fit(fit_vect)

    return lda

    
def topic_explanations(vect, model, n_top_words=5):
    """
    :param vect: fit vect
    :param model: fit topic model
    :param n_top_words: terms to describe topic
    
    :return: list of terms describing topic
    """

    # get feature names (all words from documents)
    feature_names = vect.get_feature_names()

    # only one topic, so fine to have return in for loop
    for topic in model.components_:
        return " ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]])


for label in set(km.labels_):
    # filter to only the text in one cluster
    cluster_text = sections[sections.clusters == label]['section_name']
    
    # fit a vector on the text in the cluster
    cluster_vect = TfidfVectorizer()
    fit_vect = cluster_vect.fit_transform(cluster_text)
    
    # run lda (topic model)
    lda_model = topic_model(fit_vect)
    
    # explain the text in the topic
    topic_explanation = topic_explanations(vect=cluster_vect, model=lda_model, n_top_words=5)
    
    print('Cluster={} | {}'.format(label, topic_explanation))
# Out:
# Cluster=0 | financial statements and of item
# Cluster=1 | support systems and hardware software
# Cluster=2 | item business properties proceedings legal
# Cluster=3 | stock compensation based plans and
# Cluster=4 | 31 may in millions share
# Cluster=5 | of and oracle exhibit corporation
# Cluster=6 | currency foreign translation risk presentation
# Cluster=7 | services revenues and the fiscal
# Cluster=8 | assets value fair goodwill intangible
# Cluster=9 | and accounting of accountants disclosure
# Cluster=10 | taxes income for net other
# Cluster=11 | year ended 31 may in
# Cluster=12 | information segment available geographic item
# Cluster=13 | executive item 11 compensation officers
# Cluster=14 | software and business new services
# Cluster=15 | competition
# Cluster=16 | and equity of item related
# Cluster=17 | acquisitions fiscal and employees development
# Cluster=18 | stock plan restructuring purchase repurchases
# Cluster=19 | cash flows from and activities
